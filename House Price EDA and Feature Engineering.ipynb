# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
data = pd.read_csv('train.csv')

# %%
data.head(100)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1          60       RL         65.0     8450   Pave   NaN      Reg
# 1     2          20       RL         80.0     9600   Pave   NaN      Reg
# 2     3          60       RL         68.0    11250   Pave   NaN      IR1
# 3     4          70       RL         60.0     9550   Pave   NaN      IR1
# 4     5          60       RL         84.0    14260   Pave   NaN      IR1
# ..  ...         ...      ...          ...      ...    ...   ...      ...
# 95   96          60       RL          NaN     9765   Pave   NaN      IR2
# 96   97          20       RL         78.0    10264   Pave   NaN      IR1
# 97   98          20       RL         73.0    10921   Pave   NaN      Reg
# 98   99          30       RL         85.0    10625   Pave   NaN      Reg
# 99  100          20       RL         77.0     9320   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
missingValues = [null for null in data.columns if data[null].isnull().sum()]

# %%
missingValues
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
len(missingValues)
# Out:
# 19

# %% [markdown]
# Converting Missing Data Features into binary 1 or 0 for graph

# %%
for feature in missingValues:
    dataC = data.copy()
    dataC[feature] = np.where(dataC[feature].isnull(), 1, 0)
    dataC.groupby(feature)['SalePrice'].mean().plot.bar()
    plt.title(feature)
    plt.show()

# %%
len(data.Id)
# Out:
# 1460

# %%
data = data.drop(['Id'], axis = 1)

# %%
numerical = [f for f in data.columns if data[f].dtype != 'O']
print('Number of Numerical values are:' , len(numerical))
# Out:
# Number of Numerical values are: 37

# %%
data[numerical].head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
year = [f for f in numerical if 'Year' in f or 'Yr' in f]

# %%
data[year].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0       2003          2003       2003.0    2008
# 1       1976          1976       1976.0    2007
# 2       2001          2002       2001.0    2008
# 3       1915          1970       1998.0    2006
# 4       2000          2000       2000.0    2008

# %%
data.groupby('YrSold')['SalePrice'].mean().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title("House Price vs YearSold")
# Out:
# Text(0.5, 1.0, 'House Price vs YearSold')

# %%
for f in year:
    dataC = data.copy()
    dataC.groupby(f)['SalePrice'].mean().plot()
    plt.title(f)
    plt.show()

# %%
for f in year:
    dataC = data.copy()
    dataC[f] = dataC['YrSold']-data[f]
    plt.scatter(dataC[f], dataC['SalePrice'])
    plt.xlabel(f)
    plt.ylabel('Sale Price')
    plt.show()

# %% [markdown]
# Lets separate Discrete Features

# %%
discrete = [f for f in numerical if len(data[f].unique())<25 and f not in year+['Id']]
print('Discrete Features are:', len(discrete))
data[discrete].head()
# Out:
# Discrete Features are: 17
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
# ...

# %%
for f in discrete:
    dataC = data.copy()
    dataC.groupby(f)['SalePrice'].mean().plot.bar()
    plt.show()

# %%
continuous = [f for f in numerical if f not in discrete+year+['Id']+['SalePrice']]
print('Continuous features are:', len(continuous))
data[continuous].head()
# Out:
# Continuous features are: 15
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  \
# 0          856       856       854       1710         548           0
# 1         1262      1262         0       1262         460         298
# 2          920       920       866       1786         608           0
# 3          756       961       756       1717         642           0
# 4         1145      1145      1053       2198         836         192
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch
# 0           61              0            0
# ...

# %%
for f in continuous:
    dataC = data.copy()
    dataC[f].hist()
    plt.xlabel(f)
    plt.show()

# %%
categorical = [f for f in data.columns if data[f].dtypes == 'O']
print("Categorical features are:", len(categorical))
data[categorical].head()
# Out:
# Categorical features are: 43
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
for f in categorical:
    dataC = data.copy()
    print(f, ":", len(dataC[f].unique()))
# Out:
# MSZoning : 5
# Street : 2
# Alley : 3
# LotShape : 4
# LandContour : 4
# Utilities : 2
# LotConfig : 5
# LandSlope : 3
# Neighborhood : 25
# Condition1 : 9
# Condition2 : 8
# BldgType : 5
# HouseStyle : 8
# RoofStyle : 6
# RoofMatl : 8
# Exterior1st : 15
# Exterior2nd : 16
# MasVnrType : 5
# ExterQual : 4
# ExterCond : 5
# Foundation : 6
# BsmtQual : 5
# BsmtCond : 5
# BsmtExposure : 5
# BsmtFinType1 : 7
# BsmtFinType2 : 7
# Heating : 6
# HeatingQC : 5
# CentralAir : 2
# Electrical : 6
# KitchenQual : 4
# Functional : 7
# FireplaceQu : 6
# GarageType : 7
# GarageFinish : 4
# GarageQual : 6
# GarageCond : 6
# PavedDrive : 3
# PoolQC : 4
# Fence : 5
# MiscFeature : 5
# SaleType : 9
# SaleCondition : 6

# %% [markdown]
# number of unqiue categories in categorical features

# %%
for f in categorical:
    dataC= data.copy()
    dataC.groupby(f)['SalePrice'].mean().plot.bar()
    plt.xlabel(f)
    plt.show()

# %%
shownull=data.isnull().sum()

# %%
shownull=shownull[shownull>0]
shownull.sort_values(inplace=True)
shownull.plot.bar()
len(shownull)
# Out:
# 19

# %% [markdown]
# We have separated numerical data Numerical(Discrete, Continuous, Year) to check relations with SalePrice

# %% [markdown]
# Lets Handle missing values from numerical data

# %%
data[numerical].isnull().sum()
# Out:
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
numerical_missing = [f for f in data.columns if data[f].isnull().sum()>0 and data[f].dtypes!='O']
print("Missing numerical columns are: ", len(numerical_missing))
data[numerical_missing].head()
# Out:
# Missing numerical columns are:  3
#    LotFrontage  MasVnrArea  GarageYrBlt
# 0         65.0       196.0       2003.0
# 1         80.0         0.0       1976.0
# 2         68.0       162.0       2001.0
# 3         60.0         0.0       1998.0
# 4         84.0       350.0       2000.0

# %%
mean = data[numerical_missing].mean()

# %%
mean
# Out:
# LotFrontage      70.049958
# MasVnrArea      103.685262
# GarageYrBlt    1978.506164
# dtype: float64

# %%
data[numerical_missing] = data[numerical_missing].fillna(mean)

# %%
data[numerical_missing].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# ...

# %%
checkMissing=data.isnull().sum()
checkMissing=checkMissing[checkMissing>0]
checkMissing.sort_values(inplace = True)
checkMissing.plot.bar()
len(checkMissing)
# Out:
# 16

# %%
cat_missing = [f for f in data.columns if data[f].isnull().sum()>0 and data[f].dtypes=='O']
print("Missing categorical columns are: ", len(cat_missing))
data[cat_missing].head()
# Out:
# Missing categorical columns are:  16
#   Alley MasVnrType BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# 0   NaN    BrkFace       Gd       TA           No          GLQ          Unf
# 1   NaN       None       Gd       TA           Gd          ALQ          Unf
# 2   NaN    BrkFace       Gd       TA           Mn          GLQ          Unf
# 3   NaN       None       TA       Gd           No          ALQ          Unf
# 4   NaN    BrkFace       Gd       TA           Av          GLQ          Unf
#
#   Electrical FireplaceQu GarageType GarageFinish GarageQual GarageCond PoolQC  \
# 0      SBrkr         NaN     Attchd          RFn         TA         TA    NaN
# 1      SBrkr          TA     Attchd          RFn         TA         TA    NaN
# 2      SBrkr          TA     Attchd          RFn         TA         TA    NaN
# 3      SBrkr          Gd     Detchd          Unf         TA         TA    NaN
# 4      SBrkr          TA     Attchd          RFn         TA         TA    NaN
#
# ...

# %%
mode = data[cat_missing].mode().sum()

# %%
mode
# Out:
# Alley             Grvl
# MasVnrType        None
# BsmtQual            TA
# BsmtCond            TA
# BsmtExposure        No
# BsmtFinType1       Unf
# BsmtFinType2       Unf
# Electrical       SBrkr
# FireplaceQu         Gd
# GarageType      Attchd
# GarageFinish       Unf
# GarageQual          TA
# GarageCond          TA
# PoolQC              Gd
# Fence            MnPrv
# MiscFeature       Shed
# dtype: object

# %%
data[cat_missing] = data[cat_missing].fillna(mode)

# %%
data[cat_missing].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  Grvl      Reg
# 1          20       RL         80.0     9600   Pave  Grvl      Reg
# 2          60       RL         68.0    11250   Pave  Grvl      IR1
# 3          70       RL         60.0     9550   Pave  Grvl      IR1
# 4          60       RL         84.0    14260   Pave  Grvl      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# ...

# %%
data[categorical].isnull().sum()
# Out:
# MSZoning         0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinType2     0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# KitchenQual      0
# Functional       0
# FireplaceQu      0
# GarageType       0
# GarageFinish     0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# PoolQC           0
# Fence            0
# MiscFeature      0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
checkmiss = data.isnull().sum()

# %%
checkmiss
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 80, dtype: int64

# %% [markdown]
# We have handled the missing data

# %%
dataHandledMissingValues = data.copy()

# %%
for f in categorical:
    dataC = data.copy()
    dataC.groupby(f)['SalePrice'].mean().plot.bar()
    plt.show()

# %% [markdown]
# From graphs of numerical features we can see that the data is not normally distributed hence it is skewed

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  Grvl      Reg
# 1          20       RL         80.0     9600   Pave  Grvl      Reg
# 2          60       RL         68.0    11250   Pave  Grvl      IR1
# 3          70       RL         60.0     9550   Pave  Grvl      IR1
# 4          60       RL         84.0    14260   Pave  Grvl      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# ...

# %%
data['SalePrice'].hist()

# %% [markdown]
# Our Dependent features are highly skewed

# %% [markdown]
# Applying logarithmic Transformation

# %%
data['SalePrice'] = np.log(data['SalePrice']+1)

# %%
print(data['SalePrice'].skew())
# Out:
# 0.12134661989685333

# %%
data['SalePrice'].hist()

# %% [markdown]
# Now is normally distributed

# %%
corr = data.corr()['SalePrice']

# %%
c=corr[corr>=0.5].sort_values(ascending=False)

# %%
c
# Out:
# SalePrice       1.000000
# OverallQual     0.817185
# GrLivArea       0.700927
# GarageCars      0.680625
# GarageArea      0.650888
# TotalBsmtSF     0.612134
# 1stFlrSF        0.596981
# FullBath        0.594771
# YearBuilt       0.586570
# YearRemodAdd    0.565608
# TotRmsAbvGrd    0.534422
# GarageYrBlt     0.500449
# Name: SalePrice, dtype: float64

# %%
sns.heatmap(data.corr())

# %%
sns.set(style="white")

sns.scatterplot(x='OverallQual', y='SalePrice', data=data)

# %%
sns.scatterplot(x='GrLivArea',y='SalePrice',data=data)

# %% [markdown]
# We can create function for scatter plot instead of writing same line

# %%
def scatterplot(var, df):
    sns.scatterplot(x=var, y='SalePrice', data=df)

# %%
scatterplot('GarageCars', data)

# %%
scatterplot('GarageArea', data)

# %%
scatterplot('TotalBsmtSF', data)

# %%
scatterplot('1stFlrSF', data)

# %%
scatterplot('FullBath', data)

# %%
scatterplot('TotRmsAbvGrd', data)

# %%
scatterplot('GarageYrBlt', data)

# %%
data=data[data['GrLivArea']<4000]

# %%
data.reset_index(drop=True, inplace=True,)

# %%
sns.scatterplot(x='GrLivArea', y='SalePrice', data=data)

# %%
corrF = ['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea','TotalBsmtSF', '1stFlrSF', 'FullBath', 'YearBuilt',
         'YearRemodAdd', 'TotRmsAbvGrd', 'GarageYrBlt']

# %%
sns.heatmap(data[corrF].corr(), annot = True)

# %%
from scipy import stats
import statsmodels.api as sm 
stats.probplot(data['SalePrice'], plot=plt)
# Out:
# ((array([-3.30437073, -3.04710795, -2.90403844, ...,  2.90403844,
#           3.04710795,  3.30437073]),
#   array([10.46027076, 10.47197813, 10.54273278, ..., 13.27582925,
#          13.32392858, 13.34550853])),
#  (0.39513801011722804, 12.021949506725813, 0.9959780917807467))

# %%
skew = [f for f in numerical if data[f].skew()>0.5]

# %%
data[skew].skew()
# Out:
# MSSubClass        1.406366
# LotFrontage       1.684923
# LotArea          12.587561
# OverallCond       0.690631
# MasVnrArea        2.656128
# BsmtFinSF1        0.744855
# BsmtFinSF2        4.248587
# BsmtUnfSF         0.921759
# 1stFlrSF          0.867081
# 2ndFlrSF          0.777866
# LowQualFinSF      8.998564
# GrLivArea         0.835192
# BsmtFullBath      0.591152
# BsmtHalfBath      4.128967
# HalfBath          0.684223
# KitchenAbvGr      4.481366
# TotRmsAbvGrd      0.661416
# Fireplaces        0.632678
# WoodDeckSF        1.551271
# OpenPorchSF       2.339846
# EnclosedPorch     3.084454
# 3SsnPorch        10.289866
# ScreenPorch       4.115641
# PoolArea         17.522613
# MiscVal          24.443364
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
data[skew] =pt.fit_transform(data[skew])
# Out:
# C:\Users\usama\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\preprocessing\_data.py:2970: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
stats.probplot(data['GrLivArea'], plot=plt)
# Out:
# ((array([-3.30437073, -3.04710795, -2.90403844, ...,  2.90403844,
#           3.04710795,  3.30437073]),
#   array([-4.0963238 , -3.38832617, -3.14394544, ...,  2.85945774,
#           2.96955357,  2.98744443])),
#  (1.000423380859593, 9.917478931112043e-20, 0.9984251585624979))

# %%
stats.probplot(data['LotFrontage'], plot=plt)
# Out:
# ((array([-3.30437073, -3.04710795, -2.90403844, ...,  2.90403844,
#           3.04710795,  3.30437073]),
#   array([-2.91989289, -2.91989289, -2.91989289, ...,  4.06495051,
#           4.31653468,  7.87877875])),
#  (0.9664479495771697, 1.7489770392866875e-15, 0.9645175890130574))
